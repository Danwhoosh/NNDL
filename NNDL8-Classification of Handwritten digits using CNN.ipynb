# %% [markdown]
# ## Classification of Handwritten digits using CNN

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# %%
data = datasets.load_digits()
x = data.images
y = data.target

# %%
x = x.reshape((x.shape[0], 8, 8, 1))
x = x.astype('float32')/255
y = to_categorical(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation = 'relu', input_shape = (8, 8, 1)))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
#Skip this Line

earlystop = EarlyStopping(monitor = 'val_loss', patience = 10)
best_weights = ModelCheckpoint('best_weights.h5', save_best_only = True, monitor = 'val_loss', mode = 'min')

# %%
history = model.fit(x_train, y_train, epochs = 50, batch_size = 32, validation_data = (x_test, y_test))#,callbacks = [earlystop, best_weights])
# Out:
# Epoch 1/50
# 45/45 [==============================] - 0s 4ms/step - loss: 2.2862 - accuracy: 0.2116 - val_loss: 2.2637 - val_accuracy: 0.4639
# Epoch 2/50
# 45/45 [==============================] - 0s 2ms/step - loss: 2.2167 - accuracy: 0.5894 - val_loss: 2.1497 - val_accuracy: 0.7417
# Epoch 3/50
# 45/45 [==============================] - 0s 2ms/step - loss: 2.0250 - accuracy: 0.7307 - val_loss: 1.8819 - val_accuracy: 0.6500
# Epoch 4/50
# 45/45 [==============================] - 0s 2ms/step - loss: 1.6569 - accuracy: 0.7543 - val_loss: 1.4621 - val_accuracy: 0.7722
# Epoch 5/50
# 45/45 [==============================] - 0s 2ms/step - loss: 1.2448 - accuracy: 0.7996 - val_loss: 1.0962 - val_accuracy: 0.7972
# Epoch 6/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.9253 - accuracy: 0.8358 - val_loss: 0.8546 - val_accuracy: 0.8083
# Epoch 7/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.7179 - accuracy: 0.8580 - val_loss: 0.7048 - val_accuracy: 0.8500
# Epoch 8/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5865 - accuracy: 0.8796 - val_loss: 0.6019 - val_accuracy: 0.8417
# Epoch 9/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4944 - accuracy: 0.8984 - val_loss: 0.5372 - val_accuracy: 0.8917
# Epoch 10/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.9012 - val_loss: 0.4871 - val_accuracy: 0.9000
# Epoch 11/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.9144 - val_loss: 0.4407 - val_accuracy: 0.9028
# Epoch 12/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.9172 - val_loss: 0.4287 - val_accuracy: 0.9056
# Epoch 13/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3280 - accuracy: 0.9290 - val_loss: 0.3941 - val_accuracy: 0.9167
# Epoch 14/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3004 - accuracy: 0.9360 - val_loss: 0.3648 - val_accuracy: 0.9139
# Epoch 15/50
# 45/45 [==============================] - 0s 1ms/step - loss: 0.2832 - accuracy: 0.9318 - val_loss: 0.3620 - val_accuracy: 0.9028
# Epoch 16/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.9381 - val_loss: 0.3297 - val_accuracy: 0.9139
# Epoch 17/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2480 - accuracy: 0.9402 - val_loss: 0.3404 - val_accuracy: 0.9056
# Epoch 18/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9408 - val_loss: 0.3094 - val_accuracy: 0.9333
# Epoch 19/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.2207 - accuracy: 0.9492 - val_loss: 0.2935 - val_accuracy: 0.9250
# Epoch 20/50
# 45/45 [==============================] - 0s 1ms/step - loss: 0.2085 - accuracy: 0.9492 - val_loss: 0.2995 - val_accuracy: 0.9194
# Epoch 21/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1980 - accuracy: 0.9520 - val_loss: 0.2766 - val_accuracy: 0.9389
# Epoch 22/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.9478 - val_loss: 0.2618 - val_accuracy: 0.9306
# Epoch 23/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1847 - accuracy: 0.9555 - val_loss: 0.2417 - val_accuracy: 0.9444
# Epoch 24/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1823 - accuracy: 0.9541 - val_loss: 0.2610 - val_accuracy: 0.9222
# Epoch 25/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9562 - val_loss: 0.2410 - val_accuracy: 0.9389
# Epoch 26/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9589 - val_loss: 0.2317 - val_accuracy: 0.9389
# Epoch 27/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1560 - accuracy: 0.9645 - val_loss: 0.2494 - val_accuracy: 0.9222
# Epoch 28/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1500 - accuracy: 0.9624 - val_loss: 0.2165 - val_accuracy: 0.9444
# Epoch 29/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1542 - accuracy: 0.9603 - val_loss: 0.2146 - val_accuracy: 0.9389
# Epoch 30/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9680 - val_loss: 0.1988 - val_accuracy: 0.9472
# Epoch 31/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.9659 - val_loss: 0.1971 - val_accuracy: 0.9444
# Epoch 32/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1286 - accuracy: 0.9722 - val_loss: 0.1945 - val_accuracy: 0.9361
# Epoch 33/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1243 - accuracy: 0.9708 - val_loss: 0.1820 - val_accuracy: 0.9472
# Epoch 34/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1223 - accuracy: 0.9673 - val_loss: 0.1909 - val_accuracy: 0.9389
# Epoch 35/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1186 - accuracy: 0.9708 - val_loss: 0.1727 - val_accuracy: 0.9500
# Epoch 36/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9680 - val_loss: 0.1834 - val_accuracy: 0.9417
# Epoch 37/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1152 - accuracy: 0.9708 - val_loss: 0.1722 - val_accuracy: 0.9528
# Epoch 38/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1097 - accuracy: 0.9722 - val_loss: 0.1649 - val_accuracy: 0.9500
# Epoch 39/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.9763 - val_loss: 0.1701 - val_accuracy: 0.9444
# Epoch 40/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.9743 - val_loss: 0.1577 - val_accuracy: 0.9611
# Epoch 41/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.9722 - val_loss: 0.1519 - val_accuracy: 0.9611
# Epoch 42/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.9749 - val_loss: 0.1601 - val_accuracy: 0.9611
# Epoch 43/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9756 - val_loss: 0.1664 - val_accuracy: 0.9556
# Epoch 44/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0930 - accuracy: 0.9749 - val_loss: 0.1552 - val_accuracy: 0.9639
# Epoch 45/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9798 - val_loss: 0.1487 - val_accuracy: 0.9583
# Epoch 46/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0857 - accuracy: 0.9756 - val_loss: 0.1556 - val_accuracy: 0.9389
# Epoch 47/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9791 - val_loss: 0.1400 - val_accuracy: 0.9556
# Epoch 48/50
# 45/45 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9770 - val_loss: 0.1365 - val_accuracy: 0.9611
# Epoch 49/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9777 - val_loss: 0.1369 - val_accuracy: 0.9583
# Epoch 50/50
# 45/45 [==============================] - 0s 2ms/step - loss: 0.0764 - accuracy: 0.9805 - val_loss: 0.1461 - val_accuracy: 0.9583

# %%
plt.plot(history.history['val_loss'])
plt.title('Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
plt.plot(history.history['val_accuracy'])
plt.title('Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
model.load_weights("best_weights.h5")

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose = 0)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# Test Loss: 0.0899047926068306
# Test Accuracy: 0.9777777791023254
